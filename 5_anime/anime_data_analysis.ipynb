# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'anime.csv')
data = pd.DataFrame(data)
data
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
data.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %% [markdown]
# ### 1. make a new column for episode count

# %%
data.loc[2]["Title"]
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
def extract_eposodes(txt):
    check =False
    data = ""
    for i in txt:
        if i == ")":
            check = False
            return data 
        if check ==True:
            data += i
        if i == "(":
            check = True

# %%
data.insert(2,"Episodes",data["Title"].apply(extract_eposodes))

# %%
data.Episodes = data.Episodes.str.replace(" eps","")

# %%
data.Episodes =data.Episodes.astype(int)
data
# Out:
#     Rank                                              Title  Episodes  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...        64   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...        24   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...        13   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...        51   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...        10   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...        51   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...         1   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...       148   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...        13   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...        13   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...         2   9.03
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rank      50 non-null     int64
#  1   Title     50 non-null     object
#  2   Episodes  50 non-null     int64
#  3   Score     50 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB

# %%
data.loc[3]["Title"]
# Out:
# 'Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members'

# %% [markdown]
# ### 2. make a new column for time stamp

# %%
def extraction_time(txt):
    check = False
    data = ""
    for i in range(len(txt)):
        if txt[i] ==")":
            for j in range(i+1, i+20):
                data += txt[j]
            return data

# %%
data.insert(3,"total time",data["Title"].apply(extraction_time))
data.head()
# Out:
#    Rank                                              Title  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...        10
#
#             total time  Score
# 0  Apr 2009 - Jul 2010   9.10
# 1  Apr 2011 - Sep 2011   9.07
# 2  Oct 2022 - Dec 2022   9.06
# 3  Apr 2015 - Mar 2016   9.06
# 4  Apr 2019 - Jul 2019   9.05

# %% [markdown]
# ### 3. which anime has the highest score

# %%
data[data['Score'] == data['Score'].max()]
# Out:
#    Rank                                              Title  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...        64
#
#             total time  Score
# 0  Apr 2009 - Jul 2010    9.1

# %% [markdown]
# ### 4. give me top 5 highest scoring anime

# %%
data.sort_values(by="Score", ascending=False).head(5)
# Out:
#    Rank                                              Title  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...        10
#
#             total time  Score
# 0  Apr 2009 - Jul 2010   9.10
# 1  Apr 2011 - Sep 2011   9.07
# 2  Oct 2022 - Dec 2022   9.06
# 3  Apr 2015 - Mar 2016   9.06
# 4  Apr 2019 - Jul 2019   9.05

# %% [markdown]
# ### 5. which anime has the highest episode count

# %%
data[data['Episodes'] == data['Episodes'].max()]
# Out:
#     Rank                                              Title  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...       201
#
#              total time  Score
# 15  Apr 2006 - Mar 2010   8.94

# %% [markdown]
# ### 6. animes with top 5 episode count

# %%
data.sort_values(by='Episodes', ascending=False).head(5)
# Out:
#     Rank                                              Title  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...       201
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...       148
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...       110
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...        75
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...        74
#
#              total time  Score
# 15  Apr 2006 - Mar 2010   8.94
# 7   Oct 2011 - Sep 2014   9.04
# 11  Jan 1988 - Mar 1997   9.02
# 42  Oct 2000 - Mar 2002   8.76
# 24  Apr 2004 - Sep 2005   8.87

# %% [markdown]
# ### 7. which is the longest running anime

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

data['Months'] = data['total time'].apply(calculate_total_months)

# %%
data.head(3)
# Out:
#    Rank                                              Title  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...        13
#
#             total time  Score  Months
# 0  Apr 2009 - Jul 2010   9.10      16
# 1  Apr 2011 - Sep 2011   9.07       6
# 2  Oct 2022 - Dec 2022   9.06       3

# %%
data.sort_values(by= "Months", ascending=False).head(5)
# Out:
#     Rank                                              Title  Episodes  \
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...       110
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...       201
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...       148
# 32    33  Kingdom 3rd SeasonTV (26 eps)Apr 2020 - Oct 20...        26
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...        74
#
#              total time  Score  Months
# 11  Jan 1988 - Mar 1997   9.02     111
# 15  Apr 2006 - Mar 2010   8.94      48
# 7   Oct 2011 - Sep 2014   9.04      36
# 32  Apr 2020 - Oct 2021   8.81      19
# 24  Apr 2004 - Sep 2005   8.87      18
